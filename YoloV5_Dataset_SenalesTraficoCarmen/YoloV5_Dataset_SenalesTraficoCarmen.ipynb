# %% [markdown]
# # Re-entrenamos el modelo medium de YoloV5 con el dataset entero de Kaggle

# %% [markdown]
# Añadimos acceso a la carpeta de los dataset del Drive del grupo de proyectos
#
# Importante estar ya logeados en la cuenta del grupo, da problemas si estamos en nuestra cuenta personal y queremos montar el drive de la cuenta del grupo.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importamos las bibliotecas necesarias

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# Para windows con la CPU:
# !pip3 install torch torchvision torchaudio 

# Para Windows con CUDA:
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117

# Para windows con la CPU:
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu

# Para Windows con CUDA:
# !pip3 install torch torchvision torchaudio

# Es posible que la mayoría de dependencias ya esten instaladas ^^
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (0.15.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.9/dist-packages (2.0.1+cu118)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch) (3.11.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch) (1.3.0)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Se deberia haber creado una carpeta en nuestro area de trabajo
# Si ya lo teniamos saldra el siguiente error =>fatal: destination path 'yolov5' already exists and is not an empty directory.
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15543, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 15543 (delta 60), reused 94 (delta 45), pack-reused 15393
# Receiving objects: 100% (15543/15543), 14.59 MiB | 19.40 MiB/s, done.
# Resolving deltas: 100% (10584/10584), done.

# %%
# %cd /content/yolov5
# !git pull
# %cd ../
# Out:
# /content/yolov5
# Already up to date.
# /content

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 7)) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 8)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 9)) (8.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 12)) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 13)) (1.10.1)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 15)) (2.0.0+cu118)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 16)) (0.15.1+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 17)) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 26)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 27)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.9/dist-packages (from -r yolov5/requirements.txt (line 41)) (67.6.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.25.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 26)) (2022.7.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.3.0)
# Installing collected packages: smmap, gitdb, gitpython, thop
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0 thop-0.1.1.post2209072238

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2 #Para abrir webcam
# cv2.imshow() is disabled in Colab, because it causes Jupyter sessionsto crash, consider using cv2_imshow 
from google.colab.patches import cv2_imshow 
import sys # to access the system

# Esta línea de código establece una variable de entorno llamada KMP_DUPLICATE_LIB_OK con el valor "True", lo que significa que permite la carga de bibliotecas duplicadas en el entorno de Python. Esto es útil para algunas bibliotecas de Machine Learning que usan OpenMP para acelerar el cómputo.
import os    
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %% [markdown]
# ***
# En la siguiente celda se escogen 100 imagenes para hacer el re-entreno.
#
# Además esas imagenes se suben a unas carpetas que creamos en el directorio base de colabs.
# ***

# %%
import os
import random
import shutil

# Creamos los directorios necesarios
os.makedirs('/content/data/train/images', exist_ok=True)
os.makedirs('/content/data/train/labels', exist_ok=True)
os.makedirs('/content/data/val/images', exist_ok=True)
os.makedirs('/content/data/val/labels', exist_ok=True)
os.makedirs('/content/data/test/images', exist_ok=True)
os.makedirs('/content/data/test/labels', exist_ok=True)

dest_train_Image = "/content/data/train/images/"
dest_train_Label = "/content/data/train/labels/"
dest_val_Image = "/content/data/val/images/"
dest_val_Label = "/content/data/val/labels/"
dest_test_Image = "/content/data/test/images/"
dest_test_Label = "/content/data/test/labels/"


with os.scandir('/content/drive/MyDrive/IA/Datasets/Señales_Plastico_Augmentation/train/images') as entries:
  for entry in entries:
    shutil.copy2(entry.path, dest_train_Image)

with os.scandir('/content/drive/MyDrive/IA/Datasets/Señales_Plastico_Augmentation/train/labels') as entries:
  for entry in entries:
    shutil.copy2(entry.path, dest_train_Label)

with os.scandir('/content/drive/MyDrive/IA/Datasets/Señales_Plastico_Augmentation/val/images') as entries:
  for entry in entries:
    shutil.copy2(entry.path, dest_val_Image)

with os.scandir('/content/drive/MyDrive/IA/Datasets/Señales_Plastico_Augmentation/val/labels') as entries:
  for entry in entries:
    shutil.copy2(entry.path, dest_val_Label)

# %% [markdown]
# ***
# **`Entrenar un modelo desde cero`**
# ***

# %% [markdown]
# Ahora tenemos que crear el archivo dataset.yaml, que contiene las categorias de nuestros pesos y las rutas de nuestras imagenes de entrenamiento, test y validación.

# %%
f= open("yolov5/data/dataset_senalesTraficoCarmen.yaml","w+")

#f.write("path: ../data \ntrain: train/images/ \nval: val/images \ntest: test/images \n\nnc: 4 \n\nnames: ['prohibitory', 'danger', 'mandatory', 'other']")
f.write("path: ../data \ntrain: train/images/ \nval: val/images \n\nnc: 4 \n\nnames: ['prohibitory', 'danger', 'mandatory', 'other']")

f.close()

# %%
shutil.copy2("/content/yolov5/requirements.txt", "/content/requirements.txt")
#!cd yolov5 && python train.py --img 640 --batch 16 --epochs 600 --data dataset_senalesTraficoCarmen.yaml --weights yolov5m.pt --project ../drive/MyDrive/IA/Pesos_yoloV5/Dataset_SenalesTrafico_Carmen --save-period 20
# Out:
# train: weights=yolov5m.pt, cfg=, data=dataset_senalesTraficoCarmen.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=600, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../drive/MyDrive/IA/Pesos_yoloV5/Dataset_SenalesTrafico_Carmen, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=20, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-147-gaa7c45c Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir ../drive/MyDrive/IA/Pesos_yoloV5/Dataset_SenalesTrafico_Carmen', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 49.5MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m.pt to yolov5m.pt...
# 100% 40.8M/40.8M [00:00<00:00, 73.7MB/s]
#
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     36369  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20883441 parameters, 20883441 gradients, 48.3 GFLOPs
#
# Transferred 475/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/data/train/labels... 188 images, 0 backgrounds, 0 corrupt: 100% 188/188 [00:00<00:00, 1577.71it/s]
# train: New cache created: /content/data/train/labels.cache
# val: Scanning /content/data/val/labels... 80 images, 0 backgrounds, 0 corrupt: 100% 80/80 [00:00<00:00, 601.05it/s]
# val: New cache created: /content/data/val/labels.cache
#
# AutoAnchor: 3.95 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to ../drive/MyDrive/IA/Pesos_yoloV5/Dataset_SenalesTrafico_Carmen/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to ../drive/MyDrive/IA/Pesos_yoloV5/Dataset_SenalesTrafico_Carmen/exp
# Starting training for 600 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/599      6.15G     0.1204    0.02695    0.04615         27        640: 100% 12/12 [00:11<00:00,  1.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:05<00:00,  1.73s/it]
#                    all         80         82    0.00254      0.817    0.00469   0.000994
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/599      7.37G    0.08491    0.02806    0.04103         25        640: 100% 12/12 [00:05<00:00,  2.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:03<00:00,  1.30s/it]
#                    all         80         82     0.0754      0.104      0.112     0.0276
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/599      7.38G    0.07269    0.02787    0.03911         22        640: 100% 12/12 [00:05<00:00,  2.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.34it/s]
#                    all         80         82      0.471      0.145      0.385       0.13
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/599      7.38G    0.06799    0.02263    0.03699         17        640: 100% 12/12 [00:07<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.47it/s]
#                    all         80         82      0.623      0.406      0.272     0.0875
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/599      7.38G    0.06186    0.02046    0.03497         23        640: 100% 12/12 [00:05<00:00,  2.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.00it/s]
#                    all         80         82      0.819      0.373      0.482      0.217
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/599      7.38G    0.06276    0.01947    0.03094         22        640: 100% 12/12 [00:05<00:00,  2.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.66it/s]
#                    all         80         82      0.769      0.279      0.443      0.161
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/599      7.38G    0.05757    0.01744     0.0268         29        640: 100% 12/12 [00:07<00:00,  1.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.64it/s]
#                    all         80         82      0.879      0.399      0.608      0.244
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/599      7.38G     0.0634    0.01485    0.02603         26        640: 100% 12/12 [00:05<00:00,  2.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.06it/s]
#                    all         80         82      0.598       0.55      0.562      0.227
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/599      7.38G    0.06051    0.01465    0.02538         25        640: 100% 12/12 [00:05<00:00,  2.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.83it/s]
#                    all         80         82      0.804      0.421      0.488      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/599      7.38G    0.05661    0.01301    0.02157         25        640: 100% 12/12 [00:06<00:00,  1.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.53it/s]
#                    all         80         82      0.544      0.441      0.389      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/599      7.38G    0.05944    0.01275    0.02473         27        640: 100% 12/12 [00:05<00:00,  2.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.73it/s]
#                    all         80         82      0.704      0.435      0.595       0.32
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/599      7.38G    0.05517    0.01271    0.02325         18        640: 100% 12/12 [00:06<00:00,  1.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.69it/s]
#                    all         80         82      0.311      0.796      0.379      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/599      7.38G    0.05591    0.01199    0.02337         30        640: 100% 12/12 [00:05<00:00,  2.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.14it/s]
#                    all         80         82      0.589      0.639      0.602      0.296
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/599      7.38G    0.05193    0.01122    0.02157         31        640: 100% 12/12 [00:05<00:00,  2.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.75it/s]
#                    all         80         82      0.774      0.593      0.795      0.399
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/599      7.38G    0.04678    0.01023    0.02027         21        640: 100% 12/12 [00:06<00:00,  1.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.68it/s]
#                    all         80         82      0.593      0.818      0.814      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/599      7.38G    0.05027    0.01081    0.01714         23        640: 100% 12/12 [00:06<00:00,  1.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.14it/s]
#                    all         80         82       0.61      0.842      0.792      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/599      7.38G    0.04575    0.01062    0.02155         23        640: 100% 12/12 [00:05<00:00,  2.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.62it/s]
#                    all         80         82      0.738      0.517      0.713      0.408
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/599      7.38G    0.05286    0.01033    0.01398         23        640: 100% 12/12 [00:07<00:00,  1.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.73it/s]
#                    all         80         82      0.538      0.777      0.777      0.387
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/599      7.38G     0.0463    0.01084    0.01557         30        640: 100% 12/12 [00:05<00:00,  2.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.14it/s]
#                    all         80         82      0.681      0.902      0.894      0.514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/599      7.38G    0.04585    0.01008    0.01185         19        640: 100% 12/12 [00:05<00:00,  2.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.63it/s]
#                    all         80         82      0.696      0.809       0.74      0.385
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/599      7.38G    0.04547   0.009902    0.01018         22        640: 100% 12/12 [00:07<00:00,  1.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.62it/s]
#                    all         80         82      0.546      0.802      0.689      0.373
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/599      7.38G    0.04448   0.009983    0.01695         34        640: 100% 12/12 [00:05<00:00,  2.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.13it/s]
#                    all         80         82      0.536      0.823      0.683      0.405
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/599      7.38G    0.04802   0.009755    0.01757         24        640: 100% 12/12 [00:05<00:00,  2.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.79it/s]
#                    all         80         82      0.884      0.942      0.969      0.559
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/599      7.38G    0.04523   0.009408    0.01304         24        640: 100% 12/12 [00:07<00:00,  1.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.72it/s]
#                    all         80         82      0.711      0.934      0.905       0.49
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/599      7.38G    0.04641   0.008987    0.01529         25        640: 100% 12/12 [00:05<00:00,  2.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.32it/s]
#                    all         80         82      0.861      0.906      0.919      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/599      7.38G    0.04527    0.01036    0.01387         28        640: 100% 12/12 [00:05<00:00,  2.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.64it/s]
#                    all         80         82      0.798      0.884      0.884      0.516
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/599      7.38G    0.04177   0.009488    0.01187         18        640: 100% 12/12 [00:06<00:00,  1.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.09it/s]
#                    all         80         82      0.817      0.756       0.84      0.468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/599      7.38G     0.0437   0.008931    0.01273         23        640: 100% 12/12 [00:05<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.71it/s]
#                    all         80         82      0.734      0.891      0.834      0.514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/599      7.38G    0.04122   0.009449    0.01127         28        640: 100% 12/12 [00:07<00:00,  1.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.90it/s]
#                    all         80         82      0.782        0.9      0.845      0.532
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/599      7.38G    0.04266   0.009336    0.01181         21        640: 100% 12/12 [00:05<00:00,  2.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.07it/s]
#                    all         80         82      0.663       0.87      0.784      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/599      7.38G    0.03911   0.009486    0.01277         17        640: 100% 12/12 [00:05<00:00,  2.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.79it/s]
#                    all         80         82      0.795      0.894      0.901      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/599      7.38G    0.04178    0.00915   0.009776         18        640: 100% 12/12 [00:07<00:00,  1.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.78it/s]
#                    all         80         82      0.751      0.946      0.899      0.605
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/599      7.38G    0.04308   0.008414    0.01034         18        640: 100% 12/12 [00:05<00:00,  2.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.10it/s]
#                    all         80         82        0.7      0.913      0.885      0.553
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/599      7.38G     0.0411   0.009162   0.009174         24        640: 100% 12/12 [00:05<00:00,  2.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.62it/s]
#                    all         80         82      0.839      0.837      0.947      0.649
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/599      7.38G    0.03914    0.00939   0.007298         22        640: 100% 12/12 [00:07<00:00,  1.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.66it/s]
#                    all         80         82      0.814      0.917      0.949      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/599      7.38G    0.04122   0.009325   0.009527         21        640: 100% 12/12 [00:05<00:00,  2.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.44it/s]
#                    all         80         82      0.919      0.813      0.904      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/599      7.38G    0.03588   0.009227   0.007633         22        640: 100% 12/12 [00:06<00:00,  1.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.90it/s]
#                    all         80         82      0.857       0.78      0.882      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/599      7.38G    0.03753   0.008346    0.01124         22        640: 100% 12/12 [00:06<00:00,  1.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.18it/s]
#                    all         80         82      0.907      0.828      0.913      0.457
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/599      7.38G    0.04048   0.008481   0.009332         24        640: 100% 12/12 [00:05<00:00,  2.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.58it/s]
#                    all         80         82      0.834      0.906      0.896      0.519
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/599      7.38G    0.03943   0.009613    0.00904         30        640: 100% 12/12 [00:07<00:00,  1.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.59it/s]
#                    all         80         82      0.624       0.65      0.584      0.371
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/599      7.38G    0.04055   0.008019   0.008766         16        640: 100% 12/12 [00:05<00:00,  2.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.07it/s]
#                    all         80         82      0.725      0.711      0.732        0.5
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/599      7.38G    0.03434   0.007988    0.01307         22        640: 100% 12/12 [00:05<00:00,  2.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.71it/s]
#                    all         80         82       0.84      0.885      0.873      0.551
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/599      7.38G    0.04051    0.00951    0.01308         19        640: 100% 12/12 [00:07<00:00,  1.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.73it/s]
#                    all         80         82      0.973      0.971      0.972      0.644
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/599      7.38G    0.03768   0.008696    0.01209         21        640: 100% 12/12 [00:05<00:00,  2.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.17it/s]
#                    all         80         82      0.944      0.921       0.97      0.614
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/599      7.38G    0.03715    0.00897   0.009198         24        640: 100% 12/12 [00:05<00:00,  2.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.73it/s]
#                    all         80         82      0.826      0.899      0.943      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/599      7.38G    0.03815   0.008408    0.01011         22        640: 100% 12/12 [00:06<00:00,  1.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.49it/s]
#                    all         80         82      0.847      0.801      0.891      0.618
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/599      7.38G    0.03827   0.008877    0.01036         26        640: 100% 12/12 [00:05<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.73it/s]
#                    all         80         82      0.713      0.846      0.827      0.522
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/599      7.38G    0.03934   0.008097    0.01048         24        640: 100% 12/12 [00:06<00:00,  1.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.64it/s]
#                    all         80         82      0.911      0.887      0.936      0.666
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/599      7.38G    0.03692   0.007889   0.007176         14        640: 100% 12/12 [00:06<00:00,  1.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.12it/s]
#                    all         80         82       0.94       0.96       0.98      0.705
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/599      7.38G    0.04238   0.008218    0.01141         18        640: 100% 12/12 [00:05<00:00,  2.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.63it/s]
#                    all         80         82      0.972      0.908      0.939      0.646
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/599      7.38G    0.03802   0.008204    0.01141         22        640: 100% 12/12 [00:06<00:00,  1.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.63it/s]
#                    all         80         82      0.975      0.954      0.978      0.648
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/599      7.38G    0.03892   0.007761   0.009884         17        640: 100% 12/12 [00:05<00:00,  2.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.09it/s]
#                    all         80         82      0.953      0.971      0.981      0.708
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/599      7.38G     0.0382   0.009254    0.01057         26        640: 100% 12/12 [00:06<00:00,  1.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.37it/s]
#                    all         80         82      0.931      0.931      0.972      0.634
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/599      7.38G    0.03915    0.00856   0.009561         24        640: 100% 12/12 [00:06<00:00,  1.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.56it/s]
#                    all         80         82      0.914      0.965      0.957      0.636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/599      7.38G    0.03569   0.008047   0.006616         16        640: 100% 12/12 [00:05<00:00,  2.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.10it/s]
#                    all         80         82      0.834       0.95      0.923      0.607
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/599      7.38G    0.03627   0.007932    0.01091         18        640: 100% 12/12 [00:05<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.58it/s]
#                    all         80         82      0.899      0.947      0.961      0.644
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/599      7.38G    0.03337    0.00806   0.008602         25        640: 100% 12/12 [00:07<00:00,  1.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.66it/s]
#                    all         80         82      0.952      0.967      0.979      0.689
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/599      7.38G    0.03291   0.007923   0.008743         19        640: 100% 12/12 [00:05<00:00,  2.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.86it/s]
#                    all         80         82        0.9      0.973      0.934      0.644
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/599      7.38G    0.03284   0.008189   0.008451         20        640: 100% 12/12 [00:06<00:00,  1.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.75it/s]
#                    all         80         82      0.981      0.972      0.978      0.695
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/599      7.38G    0.03463    0.00874    0.01085         26        640: 100% 12/12 [00:06<00:00,  1.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.10it/s]
#                    all         80         82       0.94      0.947      0.973      0.674
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/599      7.38G    0.03893    0.00872    0.01117         28        640: 100% 12/12 [00:05<00:00,  2.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.66it/s]
#                    all         80         82      0.945       0.96      0.975      0.662
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/599      7.38G    0.03291   0.007127   0.008552         22        640: 100% 12/12 [00:07<00:00,  1.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.76it/s]
#                    all         80         82      0.954      0.923      0.973      0.678
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/599      7.38G    0.03566   0.008528     0.0095         26        640: 100% 12/12 [00:05<00:00,  2.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.06it/s]
#                    all         80         82      0.974      0.947      0.977      0.618
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/599      7.38G    0.03529   0.007856   0.006954         23        640: 100% 12/12 [00:05<00:00,  2.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.76it/s]
#                    all         80         82       0.98      0.932       0.97      0.594
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/599      7.38G    0.03352   0.007825   0.006901         18        640: 100% 12/12 [00:07<00:00,  1.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.79it/s]
#                    all         80         82      0.961      0.919      0.962      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/599      7.38G    0.04129   0.007273   0.009084         19        640: 100% 12/12 [00:06<00:00,  1.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.10it/s]
#                    all         80         82       0.94      0.915      0.964      0.653
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/599      7.38G    0.03257    0.00722    0.00904         17        640: 100% 12/12 [00:05<00:00,  2.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.69it/s]
#                    all         80         82      0.955      0.923      0.976      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/599      7.38G    0.03581   0.007813   0.006578         22        640: 100% 12/12 [00:06<00:00,  1.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.49it/s]
#                    all         80         82      0.919      0.948      0.976      0.654
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/599      7.38G    0.03494   0.008668   0.006533         24        640: 100% 12/12 [00:05<00:00,  2.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.80it/s]
#                    all         80         82      0.918      0.944      0.971      0.673
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/599      7.38G    0.03451   0.007986   0.009548         22        640: 100% 12/12 [00:06<00:00,  1.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.71it/s]
#                    all         80         82      0.937      0.935      0.977      0.655
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/599      7.38G    0.03321   0.008028     0.0077         22        640: 100% 12/12 [00:06<00:00,  1.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.08it/s]
#                    all         80         82      0.871      0.928       0.95      0.638
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/599      7.38G    0.03066   0.007921   0.007217         22        640: 100% 12/12 [00:05<00:00,  2.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.74it/s]
#                    all         80         82      0.894      0.875      0.946      0.617
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/599      7.38G    0.03281   0.008295   0.007638         20        640: 100% 12/12 [00:07<00:00,  1.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.63it/s]
#                    all         80         82      0.955      0.932      0.977      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/599      7.38G    0.03177   0.008447   0.007229         16        640: 100% 12/12 [00:05<00:00,  2.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.17it/s]
#                    all         80         82      0.963      0.948      0.979      0.648
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/599      7.38G    0.03386   0.008202   0.005595         16        640: 100% 12/12 [00:05<00:00,  2.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.86it/s]
#                    all         80         82      0.957      0.954      0.981       0.67
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/599      7.38G    0.03177   0.007454   0.009765         17        640: 100% 12/12 [00:06<00:00,  1.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.47it/s]
#                    all         80         82      0.944      0.945      0.981      0.659
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/599      7.38G      0.034   0.008079   0.008126         20        640: 100% 12/12 [00:05<00:00,  2.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.65it/s]
#                    all         80         82      0.933      0.955      0.969      0.704
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/599      7.38G    0.03352   0.008021   0.008811         20        640: 100% 12/12 [00:06<00:00,  1.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.63it/s]
#                    all         80         82      0.932      0.962      0.982      0.608
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/599      7.38G    0.03561    0.00882   0.008306         30        640: 100% 12/12 [00:05<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:03<00:00,  1.08s/it]
#                    all         80         82       0.95      0.967      0.983      0.659
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/599      7.38G    0.03125    0.00757   0.006928         25        640: 100% 12/12 [00:05<00:00,  2.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.68it/s]
#                    all         80         82       0.95      0.961      0.982       0.68
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/599      7.38G     0.0314   0.007679   0.008218         21        640: 100% 12/12 [00:07<00:00,  1.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.58it/s]
#                    all         80         82      0.975       0.96       0.98      0.733
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/599      7.38G    0.03073   0.007517   0.009947         18        640: 100% 12/12 [00:05<00:00,  2.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.14it/s]
#                    all         80         82      0.919      0.852      0.915      0.542
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/599      7.38G    0.02894   0.008067    0.00685         25        640: 100% 12/12 [00:05<00:00,  2.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.79it/s]
#                    all         80         82      0.957      0.767      0.836      0.558
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/599      7.38G    0.03123   0.008404   0.007935         19        640: 100% 12/12 [00:07<00:00,  1.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.76it/s]
#                    all         80         82      0.911      0.893      0.921      0.562
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/599      7.38G    0.03259   0.007468    0.00581         17        640: 100% 12/12 [00:05<00:00,  2.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.13it/s]
#                    all         80         82      0.955      0.922      0.962      0.686
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/599      7.38G    0.02904   0.007878   0.005836         18        640: 100% 12/12 [00:05<00:00,  2.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.71it/s]
#                    all         80         82      0.989      0.919      0.982      0.684
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/599      7.38G    0.03203   0.007459   0.007091         21        640: 100% 12/12 [00:06<00:00,  1.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.41it/s]
#                    all         80         82      0.984      0.959      0.983      0.629
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/599      7.38G    0.03501   0.007937   0.006985         22        640: 100% 12/12 [00:05<00:00,  2.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.68it/s]
#                    all         80         82      0.916      0.963      0.964      0.659
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/599      7.38G    0.03318   0.007746   0.008278         26        640: 100% 12/12 [00:06<00:00,  1.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.68it/s]
#                    all         80         82      0.917      0.959      0.978      0.635
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/599      7.38G    0.02884   0.006933   0.007575         16        640: 100% 12/12 [00:05<00:00,  2.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.06it/s]
#                    all         80         82      0.944      0.881      0.959      0.659
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/599      7.38G    0.03306   0.007065   0.007238         21        640: 100% 12/12 [00:05<00:00,  2.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.61it/s]
#                    all         80         82      0.964      0.895      0.983       0.71
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/599      7.38G    0.03345   0.007987   0.007662         19        640: 100% 12/12 [00:08<00:00,  1.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.58it/s]
#                    all         80         82      0.944      0.903      0.976      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/599      7.38G    0.03195   0.008001   0.007218         29        640: 100% 12/12 [00:05<00:00,  2.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.47it/s]
#                    all         80         82      0.853      0.939       0.96      0.646
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/599      7.38G    0.03173   0.007814   0.008106         21        640: 100% 12/12 [00:05<00:00,  2.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.77it/s]
#                    all         80         82      0.947      0.933      0.977      0.685
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/599      7.38G    0.02867   0.007346    0.00551         22        640: 100% 12/12 [00:06<00:00,  1.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.21it/s]
#                    all         80         82      0.965      0.939      0.983      0.653
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/599      7.38G    0.03398   0.006941   0.005008         25        640: 100% 12/12 [00:05<00:00,  2.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.75it/s]
#                    all         80         82      0.936      0.947      0.978      0.728
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/599      7.38G    0.03111   0.007817   0.005548         18        640: 100% 12/12 [00:07<00:00,  1.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.90it/s]
#                    all         80         82      0.934      0.967      0.969      0.716
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/599      7.38G    0.03021   0.007499   0.006943         20        640: 100% 12/12 [00:05<00:00,  2.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.07it/s]
#                    all         80         82      0.897      0.932      0.946      0.701
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/599      7.38G    0.03557   0.007454   0.009209         20        640: 100% 12/12 [00:05<00:00,  2.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.70it/s]
#                    all         80         82      0.944      0.948      0.979      0.711
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/599      7.38G    0.03177    0.00739   0.006296         25        640: 100% 12/12 [00:07<00:00,  1.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.71it/s]
#                    all         80         82       0.99      0.963      0.983      0.714
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/599      7.38G    0.03021   0.007733   0.005012         24        640: 100% 12/12 [00:05<00:00,  2.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.49it/s]
#                    all         80         82       0.98      0.981      0.983      0.697
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/599      7.38G    0.03036   0.007168   0.006395         18        640: 100% 12/12 [00:05<00:00,  2.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.69it/s]
#                    all         80         82      0.982      0.967      0.983      0.691
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/599      7.38G    0.03125   0.008061   0.007333         28        640: 100% 12/12 [00:06<00:00,  1.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.33it/s]
#                    all         80         82      0.993      0.954      0.983      0.712
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/599      7.38G    0.02999   0.007575   0.006008         24        640: 100% 12/12 [00:04<00:00,  2.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.67it/s]
#                    all         80         82      0.979       0.92      0.978      0.747
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 640, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 529, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/yolov5/train.py", line 386, in train
#     torch.save(ckpt, last)
#   File "/usr/local/lib/python3.9/dist-packages/torch/serialization.py", line 440, in save
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 980, in _bootstrap_inner
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/pin_memory.py", line 51, in _pin_memory_loop
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/pin_memory.py", line 51, in _pin_memory_loop
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/usr/local/lib/python3.9/dist-packages/torch/serialization.py", line 315, in _open_zipfile_writer
#     return container(name_or_buffer)
#   File "/usr/local/lib/python3.9/dist-packages/torch/serialization.py", line 288, in __init__
#     super().__init__(torch._C.PyTorchFileWriter(str(name)))
# KeyboardInterrupt
#     do_one_step()
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/pin_memory.py", line 28, in do_one_step
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.9/multiprocessing/queues.py", line 122, in get
#     do_one_step()
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/data/_utils/pin_memory.py", line 28, in do_one_step
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.9/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/local/lib/python3.9/dist-packages/torch/multiprocessing/reductions.py", line 307, in rebuild_storage_fd
#     return _ForkingPickler.loads(res)
#   File "/usr/local/lib/python3.9/dist-packages/torch/multiprocessing/reductions.py", line 307, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.9/multiprocessing/resource_sharer.py", line 57, in detach
#     fd = df.detach()
#   File "/usr/lib/python3.9/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.9/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.9/multiprocessing/connection.py", line 502, in Client
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.9/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.9/multiprocessing/connection.py", line 502, in Client
#     c = SocketClient(address)
#   File "/usr/lib/python3.9/multiprocessing/connection.py", line 630, in SocketClient
#     c = SocketClient(address)
#   File "/usr/lib/python3.9/multiprocessing/connection.py", line 630, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# ^C

# %%
 # !cd yolov5 && python train.py --resume ../drive/MyDrive/IA/Pesos_yoloV5/Dataset_Completo/exp/weights/last.pt

# %% [markdown]
# ***
# **`Cargamos nuestro modelo`**
# ***

# %%
# modelo = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/IA/Pesos_yoloV5/Dataset_Completo/exp/weights/best.pt', force_reload=True)

# %%
# import os

# with os.scandir('/content/drive/MyDrive/IA/Datasets/Señales_Plastico/') as entries:
#   for src_img in entries:
#     # print(src_img.path)
#     results = modelo(src_img.path)
#     plt.imshow(np.squeeze(results.render()))
#     plt.show()
